# %%
import pandas as pd

df_train = pd.read_csv("./metadata_split/train_metaData.csv")
df_val = pd.read_csv("./metadata_split/val_metaData.csv")
df_test = pd.read_csv("./metadata_split/test_metaData.csv")

drop_cols = ["image", "filename", "stem", "Date", "donor_id", "unique_donor_id", "year.1"]

drop_cols_all = drop_cols

df_reduced_train = df_train.drop(columns=drop_cols_all, errors="ignore")
df_reduced_val = df_val.drop(columns=drop_cols_all, errors="ignore")
df_reduced_test = df_test.drop(columns=drop_cols_all, errors="ignore")

print("Remaining columns:", df_reduced_train.columns.tolist())
print("Num remaining:", len(df_reduced_train.columns))
# Out:
# Remaining columns: ['class_label', 'year', 'wind_dir', 'season', 'img_f397', 'img_f492', 'img_f339', 'img_f392', 'img_f142', 'img_f311', 'img_f743', 'img_f888', 'img_f1947', 'img_f1763', 'img_f1123', 'img_f1806', 'img_f1713', 'img_f1549', 'img_f1260', 'img_f1105', 'img_f1018', 'img_f27', 'img_f38', 'img_f840', 'img_f1639', 'img_f92', 'img_f764', 'img_f14', 'img_f1170', 'img_f496', 'img_f717', 'img_f879', 'img_f558', 'img_f1871', 'img_f1133', 'img_f994', 'img_f335', 'img_f1309', 'img_f1271', 'img_f809', 'img_f2047', 'img_f987', 'img_f30', 'img_f1373', 'img_f1458', 'img_f58', 'img_f1295', 'img_f1625', 'img_f1243', 'img_f674', 'img_f246', 'img_f1998', 'img_f744', 'img_f1501', 'img_f657', 'img_f898', 'img_f974', 'img_f1924', 'img_f1881', 'img_f211', 'img_f931', 'img_f1411', 'img_f1204', 'img_f93', 'img_f2042', 'img_f410', 'img_f1985', 'img_f1572', 'img_f379', 'img_f21', 'img_f459', 'img_f798', 'img_f1635', 'img_f1391', 'img_f1199', 'img_f248', 'img_f1016', 'img_f1423', 'img_f1000', 'img_f1457', 'img_f88', 'img_f175', 'img_f926', 'img_f753', 'img_f250', 'img_f1388', 'img_f370', 'img_f357', 'img_f1844', 'img_f446', 'img_f1805', 'img_f1327', 'img_f324', 'img_f1696', 'img_f1014', 'img_f1281', 'img_f1611', 'img_f104', 'img_f667', 'img_f531', 'img_f683', 'img_f1542', 'img_f886', 'img_f826', 'img_f1975', 'img_f1721', 'img_f1350', 'img_f903', 'img_f1648', 'img_f1320', 'img_f1555', 'img_f1599', 'img_f1995', 'img_f279', 'img_f1408', 'img_f746', 'img_f1477', 'img_f1800', 'img_f1808', 'img_f513', 'img_f1944', 'img_f1394', 'img_f833', 'img_f541', 'img_f1732', 'img_f1854', 'img_f600', 'img_f1030', 'img_f1058', 'img_f2017', 'img_f381', 'img_f922', 'img_f1368', 'img_f1502', 'img_f851', 'img_f1113', 'img_f1041', 'img_f942', 'img_f215', 'img_f234', 'img_f1444', 'img_f647', 'img_f1426', 'img_f990', 'img_f693', 'img_f15', 'img_f935', 'img_f1168', 'img_f1242', 'img_f1167', 'img_f984', 'img_f26', 'img_f756', 'img_f179', 'img_f741', 'img_f1865', 'img_f1943', 'img_f1942', 'img_f1342', 'img_f151', 'img_f29', 'img_f1567', 'img_f507', 'img_f241', 'img_f1910', 'img_f60', 'img_f2031', 'img_f817', 'img_f1049', 'img_f1968', 'img_f981', 'img_f1546', 'img_f91', 'img_f323', 'img_f701', 'img_f1205', 'img_f1716', 'img_f1843', 'img_f1071', 'img_f1107', 'img_f1463', 'img_f1752', 'img_f1946', 'img_f1864', 'img_f1631', 'img_f1165', 'img_f788', 'img_f1901', 'img_f1905', 'img_f745', 'img_f1667', 'img_f469', 'img_f36', 'img_f2002', 'img_f999', 'img_f1331', 'img_f1238', 'img_f1307', 'img_f580', 'img_f1355', 'img_f1068', 'img_f1382', 'img_f1972', 'img_f1509', 'img_f398', 'img_f134', 'img_f1337', 'img_f528', 'img_f697', 'img_f1379', 'img_f1691', 'img_f839', 'img_f847', 'img_f723', 'img_f725', 'img_f1479', 'img_f1442', 'img_f282', 'img_f445', 'img_f438', 'img_f1566', 'img_f1613', 'img_f1994', 'img_f966', 'img_f1403', 'img_f125', 'img_f116', 'img_f114', 'img_f1616', 'img_f238', 'img_f1700', 'img_f97', 'img_f1178', 'img_f526', 'img_f42', 'img_f1038', 'img_f1034', 'img_f1027', 'img_f1819', 'img_f1480', 'img_f767', 'img_f636', 'img_f1971', 'img_f52', 'img_f1347', 'img_f1142', 'img_f1967', 'img_f1916', 'img_f1893', 'img_f1877', 'img_f304', 'img_f1356', 'img_f593', 'img_f1308', 'img_f236', 'img_f242', 'img_f220', 'img_f183', 'img_f1641', 'img_f810', 'img_f1078', 'img_f1301', 'img_f5', 'img_f18', 'Wind_Run', 'img_f911', 'img_f890', 'img_f1551', 'img_f1534', 'img_f1545', 'img_f368', 'img_f364', 'img_f1973', 'img_f1535', 'img_f1001', 'img_f721', 'img_f353', 'img_f1588', 'img_f1558', 'img_f2023', 'img_f1596', 'img_f385', 'img_f396', 'img_f1478', 'img_f422', 'img_f1640', 'img_f835', 'img_f1076', 'img_f1315', 'img_f1303', 'img_f581', 'img_f219', 'img_f224', 'img_f1719', 'img_f1729', 'img_f1727', 'img_f557', 'img_f564', 'img_f49', 'img_f1248', 'img_f1244', 'img_f616', 'img_f1270', 'img_f1291', 'img_f300', 'img_f1139', 'img_f759', 'img_f1785', 'img_f630', 'img_f650', 'img_f1267', 'img_f1949', 'img_f758', 'img_f1120', 'img_f1821', 'img_f144', 'img_f698', 'img_f1214', 'img_f659', 'img_f1799', ...
# Num remaining: 1542

# %%
import pandas as pd

df = df_reduced_train.copy()


label_map = {
    "FRESH": 0,
    "BLOAT": 1,
    "ACTIVE_DECAY": 2,
    "ADVANCED_DECAY": 3
}
df["class_label_encoded"] = df["class_label"].map(label_map)

# check mapping
print("Encoded target preview")
print(df[["class_label", "class_label_encoded"]].drop_duplicates())


numeric_cols = df.select_dtypes(include=["number"]).columns.tolist()
string_cols = df.select_dtypes(include=["object", "string"]).columns.tolist()


print("\nNumeric columns")
print(numeric_cols)

print("\nString columns")
print(string_cols)


print("\nString columns with unique counts")
for col in string_cols:
    print(f"{col}: unique={df[col].nunique(dropna=True)}, avg_len={df[col].astype(str).str.len().mean():.2f}")

target_col = "class_label_encoded"
raw_target_col = "class_label"


# input categorical columns only
categorical_cols = ["wind_dir", "season"]
categorical_cols = [c for c in categorical_cols if c in df.columns]

print("\nTarget column")
print(target_col)

print("\nInput categorical columns")
print(categorical_cols)


df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=False)
df_encoded = df_encoded.drop(columns=[raw_target_col], errors="ignore")

print("\nFinal columns after one-hot encoding")
print(df_encoded.columns.tolist())

print("\nFinal shape")
print(df_encoded.shape)

df_encoded.to_csv("./metadata_split/train_processed_data.csv", index=False)
print("\nSaved to train processed_data.csv")
# Out:
# Encoded target preview
#         class_label  class_label_encoded
# 0             FRESH                    0
# 47            BLOAT                    1
# 186    ACTIVE_DECAY                    2
# 290  ADVANCED_DECAY                    3
#
# Numeric columns
# ['year', 'img_f397', 'img_f492', 'img_f339', 'img_f392', 'img_f142', 'img_f311', 'img_f743', 'img_f888', 'img_f1947', 'img_f1763', 'img_f1123', 'img_f1806', 'img_f1713', 'img_f1549', 'img_f1260', 'img_f1105', 'img_f1018', 'img_f27', 'img_f38', 'img_f840', 'img_f1639', 'img_f92', 'img_f764', 'img_f14', 'img_f1170', 'img_f496', 'img_f717', 'img_f879', 'img_f558', 'img_f1871', 'img_f1133', 'img_f994', 'img_f335', 'img_f1309', 'img_f1271', 'img_f809', 'img_f2047', 'img_f987', 'img_f30', 'img_f1373', 'img_f1458', 'img_f58', 'img_f1295', 'img_f1625', 'img_f1243', 'img_f674', 'img_f246', 'img_f1998', 'img_f744', 'img_f1501', 'img_f657', 'img_f898', 'img_f974', 'img_f1924', 'img_f1881', 'img_f211', 'img_f931', 'img_f1411', 'img_f1204', 'img_f93', 'img_f2042', 'img_f410', 'img_f1985', 'img_f1572', 'img_f379', 'img_f21', 'img_f459', 'img_f798', 'img_f1635', 'img_f1391', 'img_f1199', 'img_f248', 'img_f1016', 'img_f1423', 'img_f1000', 'img_f1457', 'img_f88', 'img_f175', 'img_f926', 'img_f753', 'img_f250', 'img_f1388', 'img_f370', 'img_f357', 'img_f1844', 'img_f446', 'img_f1805', 'img_f1327', 'img_f324', 'img_f1696', 'img_f1014', 'img_f1281', 'img_f1611', 'img_f104', 'img_f667', 'img_f531', 'img_f683', 'img_f1542', 'img_f886', 'img_f826', 'img_f1975', 'img_f1721', 'img_f1350', 'img_f903', 'img_f1648', 'img_f1320', 'img_f1555', 'img_f1599', 'img_f1995', 'img_f279', 'img_f1408', 'img_f746', 'img_f1477', 'img_f1800', 'img_f1808', 'img_f513', 'img_f1944', 'img_f1394', 'img_f833', 'img_f541', 'img_f1732', 'img_f1854', 'img_f600', 'img_f1030', 'img_f1058', 'img_f2017', 'img_f381', 'img_f922', 'img_f1368', 'img_f1502', 'img_f851', 'img_f1113', 'img_f1041', 'img_f942', 'img_f215', 'img_f234', 'img_f1444', 'img_f647', 'img_f1426', 'img_f990', 'img_f693', 'img_f15', 'img_f935', 'img_f1168', 'img_f1242', 'img_f1167', 'img_f984', 'img_f26', 'img_f756', 'img_f179', 'img_f741', 'img_f1865', 'img_f1943', 'img_f1942', 'img_f1342', 'img_f151', 'img_f29', 'img_f1567', 'img_f507', 'img_f241', 'img_f1910', 'img_f60', 'img_f2031', 'img_f817', 'img_f1049', 'img_f1968', 'img_f981', 'img_f1546', 'img_f91', 'img_f323', 'img_f701', 'img_f1205', 'img_f1716', 'img_f1843', 'img_f1071', 'img_f1107', 'img_f1463', 'img_f1752', 'img_f1946', 'img_f1864', 'img_f1631', 'img_f1165', 'img_f788', 'img_f1901', 'img_f1905', 'img_f745', 'img_f1667', 'img_f469', 'img_f36', 'img_f2002', 'img_f999', 'img_f1331', 'img_f1238', 'img_f1307', 'img_f580', 'img_f1355', 'img_f1068', 'img_f1382', 'img_f1972', 'img_f1509', 'img_f398', 'img_f134', 'img_f1337', 'img_f528', 'img_f697', 'img_f1379', 'img_f1691', 'img_f839', 'img_f847', 'img_f723', 'img_f725', 'img_f1479', 'img_f1442', 'img_f282', 'img_f445', 'img_f438', 'img_f1566', 'img_f1613', 'img_f1994', 'img_f966', 'img_f1403', 'img_f125', 'img_f116', 'img_f114', 'img_f1616', 'img_f238', 'img_f1700', 'img_f97', 'img_f1178', 'img_f526', 'img_f42', 'img_f1038', 'img_f1034', 'img_f1027', 'img_f1819', 'img_f1480', 'img_f767', 'img_f636', 'img_f1971', 'img_f52', 'img_f1347', 'img_f1142', 'img_f1967', 'img_f1916', 'img_f1893', 'img_f1877', 'img_f304', 'img_f1356', 'img_f593', 'img_f1308', 'img_f236', 'img_f242', 'img_f220', 'img_f183', 'img_f1641', 'img_f810', 'img_f1078', 'img_f1301', 'img_f5', 'img_f18', 'Wind_Run', 'img_f911', 'img_f890', 'img_f1551', 'img_f1534', 'img_f1545', 'img_f368', 'img_f364', 'img_f1973', 'img_f1535', 'img_f1001', 'img_f721', 'img_f353', 'img_f1588', 'img_f1558', 'img_f2023', 'img_f1596', 'img_f385', 'img_f396', 'img_f1478', 'img_f422', 'img_f1640', 'img_f835', 'img_f1076', 'img_f1315', 'img_f1303', 'img_f581', 'img_f219', 'img_f224', 'img_f1719', 'img_f1729', 'img_f1727', 'img_f557', 'img_f564', 'img_f49', 'img_f1248', 'img_f1244', 'img_f616', 'img_f1270', 'img_f1291', 'img_f300', 'img_f1139', 'img_f759', 'img_f1785', 'img_f630', 'img_f650', 'img_f1267', 'img_f1949', 'img_f758', 'img_f1120', 'img_f1821', 'img_f144', 'img_f698', 'img_f1214', 'img_f659', 'img_f1799', 'img_f988', 'img_f781', 'img_f94', 'img_f1192', 'img_f1 ...
#
# String columns
# ['class_label', 'wind_dir', 'season']
#
# String columns with unique counts
# class_label: unique=4, avg_len=9.81
# wind_dir: unique=9, avg_len=2.35
# season: unique=3, avg_len=6.00
#
# Target column
# class_label_encoded
#
# Input categorical columns
# ['wind_dir', 'season']
#
# Final columns after one-hot encoding
# ['year', 'img_f397', 'img_f492', 'img_f339', 'img_f392', 'img_f142', 'img_f311', 'img_f743', 'img_f888', 'img_f1947', 'img_f1763', 'img_f1123', 'img_f1806', 'img_f1713', 'img_f1549', 'img_f1260', 'img_f1105', 'img_f1018', 'img_f27', 'img_f38', 'img_f840', 'img_f1639', 'img_f92', 'img_f764', 'img_f14', 'img_f1170', 'img_f496', 'img_f717', 'img_f879', 'img_f558', 'img_f1871', 'img_f1133', 'img_f994', 'img_f335', 'img_f1309', 'img_f1271', 'img_f809', 'img_f2047', 'img_f987', 'img_f30', 'img_f1373', 'img_f1458', 'img_f58', 'img_f1295', 'img_f1625', 'img_f1243', 'img_f674', 'img_f246', 'img_f1998', 'img_f744', 'img_f1501', 'img_f657', 'img_f898', 'img_f974', 'img_f1924', 'img_f1881', 'img_f211', 'img_f931', 'img_f1411', 'img_f1204', 'img_f93', 'img_f2042', 'img_f410', 'img_f1985', 'img_f1572', 'img_f379', 'img_f21', 'img_f459', 'img_f798', 'img_f1635', 'img_f1391', 'img_f1199', 'img_f248', 'img_f1016', 'img_f1423', 'img_f1000', 'img_f1457', 'img_f88', 'img_f175', 'img_f926', 'img_f753', 'img_f250', 'img_f1388', 'img_f370', 'img_f357', 'img_f1844', 'img_f446', 'img_f1805', 'img_f1327', 'img_f324', 'img_f1696', 'img_f1014', 'img_f1281', 'img_f1611', 'img_f104', 'img_f667', 'img_f531', 'img_f683', 'img_f1542', 'img_f886', 'img_f826', 'img_f1975', 'img_f1721', 'img_f1350', 'img_f903', 'img_f1648', 'img_f1320', 'img_f1555', 'img_f1599', 'img_f1995', 'img_f279', 'img_f1408', 'img_f746', 'img_f1477', 'img_f1800', 'img_f1808', 'img_f513', 'img_f1944', 'img_f1394', 'img_f833', 'img_f541', 'img_f1732', 'img_f1854', 'img_f600', 'img_f1030', 'img_f1058', 'img_f2017', 'img_f381', 'img_f922', 'img_f1368', 'img_f1502', 'img_f851', 'img_f1113', 'img_f1041', 'img_f942', 'img_f215', 'img_f234', 'img_f1444', 'img_f647', 'img_f1426', 'img_f990', 'img_f693', 'img_f15', 'img_f935', 'img_f1168', 'img_f1242', 'img_f1167', 'img_f984', 'img_f26', 'img_f756', 'img_f179', 'img_f741', 'img_f1865', 'img_f1943', 'img_f1942', 'img_f1342', 'img_f151', 'img_f29', 'img_f1567', 'img_f507', 'img_f241', 'img_f1910', 'img_f60', 'img_f2031', 'img_f817', 'img_f1049', 'img_f1968', 'img_f981', 'img_f1546', 'img_f91', 'img_f323', 'img_f701', 'img_f1205', 'img_f1716', 'img_f1843', 'img_f1071', 'img_f1107', 'img_f1463', 'img_f1752', 'img_f1946', 'img_f1864', 'img_f1631', 'img_f1165', 'img_f788', 'img_f1901', 'img_f1905', 'img_f745', 'img_f1667', 'img_f469', 'img_f36', 'img_f2002', 'img_f999', 'img_f1331', 'img_f1238', 'img_f1307', 'img_f580', 'img_f1355', 'img_f1068', 'img_f1382', 'img_f1972', 'img_f1509', 'img_f398', 'img_f134', 'img_f1337', 'img_f528', 'img_f697', 'img_f1379', 'img_f1691', 'img_f839', 'img_f847', 'img_f723', 'img_f725', 'img_f1479', 'img_f1442', 'img_f282', 'img_f445', 'img_f438', 'img_f1566', 'img_f1613', 'img_f1994', 'img_f966', 'img_f1403', 'img_f125', 'img_f116', 'img_f114', 'img_f1616', 'img_f238', 'img_f1700', 'img_f97', 'img_f1178', 'img_f526', 'img_f42', 'img_f1038', 'img_f1034', 'img_f1027', 'img_f1819', 'img_f1480', 'img_f767', 'img_f636', 'img_f1971', 'img_f52', 'img_f1347', 'img_f1142', 'img_f1967', 'img_f1916', 'img_f1893', 'img_f1877', 'img_f304', 'img_f1356', 'img_f593', 'img_f1308', 'img_f236', 'img_f242', 'img_f220', 'img_f183', 'img_f1641', 'img_f810', 'img_f1078', 'img_f1301', 'img_f5', 'img_f18', 'Wind_Run', 'img_f911', 'img_f890', 'img_f1551', 'img_f1534', 'img_f1545', 'img_f368', 'img_f364', 'img_f1973', 'img_f1535', 'img_f1001', 'img_f721', 'img_f353', 'img_f1588', 'img_f1558', 'img_f2023', 'img_f1596', 'img_f385', 'img_f396', 'img_f1478', 'img_f422', 'img_f1640', 'img_f835', 'img_f1076', 'img_f1315', 'img_f1303', 'img_f581', 'img_f219', 'img_f224', 'img_f1719', 'img_f1729', 'img_f1727', 'img_f557', 'img_f564', 'img_f49', 'img_f1248', 'img_f1244', 'img_f616', 'img_f1270', 'img_f1291', 'img_f300', 'img_f1139', 'img_f759', 'img_f1785', 'img_f630', 'img_f650', 'img_f1267', 'img_f1949', 'img_f758', 'img_f1120', 'img_f1821', 'img_f144', 'img_f698', 'img_f1214', 'img_f659', 'img_f1799', 'img_f988', 'img_f781', 'img_f94', 'img_f1192', 'img_f1 ...
#
# Final shape
# (449, 1552)
#
# Saved to train processed_data.csv

# %%
import pandas as pd

df = df_reduced_val.copy()


label_map = {
    "FRESH": 0,
    "BLOAT": 1,
    "ACTIVE_DECAY": 2,
    "ADVANCED_DECAY": 3
}
df["class_label_encoded"] = df["class_label"].map(label_map)

# check mapping
print("Encoded target preview")
print(df[["class_label", "class_label_encoded"]].drop_duplicates())


numeric_cols = df.select_dtypes(include=["number"]).columns.tolist()
string_cols = df.select_dtypes(include=["object", "string"]).columns.tolist()


print("\nNumeric columns")
print(numeric_cols)

print("\nString columns")
print(string_cols)


print("\nString columns with unique counts")
for col in string_cols:
    print(f"{col}: unique={df[col].nunique(dropna=True)}, avg_len={df[col].astype(str).str.len().mean():.2f}")

target_col = "class_label_encoded"
raw_target_col = "class_label"


# input categorical columns only
categorical_cols = ["wind_dir", "season"]
categorical_cols = [c for c in categorical_cols if c in df.columns]

print("\nTarget column")
print(target_col)

print("\nInput categorical columns")
print(categorical_cols)


df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=False)
df_encoded = df_encoded.drop(columns=[raw_target_col], errors="ignore")

print("\nFinal columns after one-hot encoding")
print(df_encoded.columns.tolist())

print("\nFinal shape")
print(df_encoded.shape)

df_encoded.to_csv("./metadata_split/val_processed_data.csv", index=False)
print("\nSaved to val processed_data.csv")
# Out:
# Encoded target preview
#         class_label  class_label_encoded
# 0             FRESH                    0
# 18            BLOAT                    1
# 62     ACTIVE_DECAY                    2
# 101  ADVANCED_DECAY                    3
#
# Numeric columns
# ['year', 'img_f397', 'img_f492', 'img_f339', 'img_f392', 'img_f142', 'img_f311', 'img_f743', 'img_f888', 'img_f1947', 'img_f1763', 'img_f1123', 'img_f1806', 'img_f1713', 'img_f1549', 'img_f1260', 'img_f1105', 'img_f1018', 'img_f27', 'img_f38', 'img_f840', 'img_f1639', 'img_f92', 'img_f764', 'img_f14', 'img_f1170', 'img_f496', 'img_f717', 'img_f879', 'img_f558', 'img_f1871', 'img_f1133', 'img_f994', 'img_f335', 'img_f1309', 'img_f1271', 'img_f809', 'img_f2047', 'img_f987', 'img_f30', 'img_f1373', 'img_f1458', 'img_f58', 'img_f1295', 'img_f1625', 'img_f1243', 'img_f674', 'img_f246', 'img_f1998', 'img_f744', 'img_f1501', 'img_f657', 'img_f898', 'img_f974', 'img_f1924', 'img_f1881', 'img_f211', 'img_f931', 'img_f1411', 'img_f1204', 'img_f93', 'img_f2042', 'img_f410', 'img_f1985', 'img_f1572', 'img_f379', 'img_f21', 'img_f459', 'img_f798', 'img_f1635', 'img_f1391', 'img_f1199', 'img_f248', 'img_f1016', 'img_f1423', 'img_f1000', 'img_f1457', 'img_f88', 'img_f175', 'img_f926', 'img_f753', 'img_f250', 'img_f1388', 'img_f370', 'img_f357', 'img_f1844', 'img_f446', 'img_f1805', 'img_f1327', 'img_f324', 'img_f1696', 'img_f1014', 'img_f1281', 'img_f1611', 'img_f104', 'img_f667', 'img_f531', 'img_f683', 'img_f1542', 'img_f886', 'img_f826', 'img_f1975', 'img_f1721', 'img_f1350', 'img_f903', 'img_f1648', 'img_f1320', 'img_f1555', 'img_f1599', 'img_f1995', 'img_f279', 'img_f1408', 'img_f746', 'img_f1477', 'img_f1800', 'img_f1808', 'img_f513', 'img_f1944', 'img_f1394', 'img_f833', 'img_f541', 'img_f1732', 'img_f1854', 'img_f600', 'img_f1030', 'img_f1058', 'img_f2017', 'img_f381', 'img_f922', 'img_f1368', 'img_f1502', 'img_f851', 'img_f1113', 'img_f1041', 'img_f942', 'img_f215', 'img_f234', 'img_f1444', 'img_f647', 'img_f1426', 'img_f990', 'img_f693', 'img_f15', 'img_f935', 'img_f1168', 'img_f1242', 'img_f1167', 'img_f984', 'img_f26', 'img_f756', 'img_f179', 'img_f741', 'img_f1865', 'img_f1943', 'img_f1942', 'img_f1342', 'img_f151', 'img_f29', 'img_f1567', 'img_f507', 'img_f241', 'img_f1910', 'img_f60', 'img_f2031', 'img_f817', 'img_f1049', 'img_f1968', 'img_f981', 'img_f1546', 'img_f91', 'img_f323', 'img_f701', 'img_f1205', 'img_f1716', 'img_f1843', 'img_f1071', 'img_f1107', 'img_f1463', 'img_f1752', 'img_f1946', 'img_f1864', 'img_f1631', 'img_f1165', 'img_f788', 'img_f1901', 'img_f1905', 'img_f745', 'img_f1667', 'img_f469', 'img_f36', 'img_f2002', 'img_f999', 'img_f1331', 'img_f1238', 'img_f1307', 'img_f580', 'img_f1355', 'img_f1068', 'img_f1382', 'img_f1972', 'img_f1509', 'img_f398', 'img_f134', 'img_f1337', 'img_f528', 'img_f697', 'img_f1379', 'img_f1691', 'img_f839', 'img_f847', 'img_f723', 'img_f725', 'img_f1479', 'img_f1442', 'img_f282', 'img_f445', 'img_f438', 'img_f1566', 'img_f1613', 'img_f1994', 'img_f966', 'img_f1403', 'img_f125', 'img_f116', 'img_f114', 'img_f1616', 'img_f238', 'img_f1700', 'img_f97', 'img_f1178', 'img_f526', 'img_f42', 'img_f1038', 'img_f1034', 'img_f1027', 'img_f1819', 'img_f1480', 'img_f767', 'img_f636', 'img_f1971', 'img_f52', 'img_f1347', 'img_f1142', 'img_f1967', 'img_f1916', 'img_f1893', 'img_f1877', 'img_f304', 'img_f1356', 'img_f593', 'img_f1308', 'img_f236', 'img_f242', 'img_f220', 'img_f183', 'img_f1641', 'img_f810', 'img_f1078', 'img_f1301', 'img_f5', 'img_f18', 'Wind_Run', 'img_f911', 'img_f890', 'img_f1551', 'img_f1534', 'img_f1545', 'img_f368', 'img_f364', 'img_f1973', 'img_f1535', 'img_f1001', 'img_f721', 'img_f353', 'img_f1588', 'img_f1558', 'img_f2023', 'img_f1596', 'img_f385', 'img_f396', 'img_f1478', 'img_f422', 'img_f1640', 'img_f835', 'img_f1076', 'img_f1315', 'img_f1303', 'img_f581', 'img_f219', 'img_f224', 'img_f1719', 'img_f1729', 'img_f1727', 'img_f557', 'img_f564', 'img_f49', 'img_f1248', 'img_f1244', 'img_f616', 'img_f1270', 'img_f1291', 'img_f300', 'img_f1139', 'img_f759', 'img_f1785', 'img_f630', 'img_f650', 'img_f1267', 'img_f1949', 'img_f758', 'img_f1120', 'img_f1821', 'img_f144', 'img_f698', 'img_f1214', 'img_f659', 'img_f1799', 'img_f988', 'img_f781', 'img_f94', 'img_f1192', 'img_f1 ...
#
# String columns
# ['class_label', 'wind_dir', 'season']
#
# String columns with unique counts
# class_label: unique=4, avg_len=9.61
# wind_dir: unique=7, avg_len=2.67
# season: unique=2, avg_len=5.98
#
# Target column
# class_label_encoded
#
# Input categorical columns
# ['wind_dir', 'season']
#
# Final columns after one-hot encoding
# ['year', 'img_f397', 'img_f492', 'img_f339', 'img_f392', 'img_f142', 'img_f311', 'img_f743', 'img_f888', 'img_f1947', 'img_f1763', 'img_f1123', 'img_f1806', 'img_f1713', 'img_f1549', 'img_f1260', 'img_f1105', 'img_f1018', 'img_f27', 'img_f38', 'img_f840', 'img_f1639', 'img_f92', 'img_f764', 'img_f14', 'img_f1170', 'img_f496', 'img_f717', 'img_f879', 'img_f558', 'img_f1871', 'img_f1133', 'img_f994', 'img_f335', 'img_f1309', 'img_f1271', 'img_f809', 'img_f2047', 'img_f987', 'img_f30', 'img_f1373', 'img_f1458', 'img_f58', 'img_f1295', 'img_f1625', 'img_f1243', 'img_f674', 'img_f246', 'img_f1998', 'img_f744', 'img_f1501', 'img_f657', 'img_f898', 'img_f974', 'img_f1924', 'img_f1881', 'img_f211', 'img_f931', 'img_f1411', 'img_f1204', 'img_f93', 'img_f2042', 'img_f410', 'img_f1985', 'img_f1572', 'img_f379', 'img_f21', 'img_f459', 'img_f798', 'img_f1635', 'img_f1391', 'img_f1199', 'img_f248', 'img_f1016', 'img_f1423', 'img_f1000', 'img_f1457', 'img_f88', 'img_f175', 'img_f926', 'img_f753', 'img_f250', 'img_f1388', 'img_f370', 'img_f357', 'img_f1844', 'img_f446', 'img_f1805', 'img_f1327', 'img_f324', 'img_f1696', 'img_f1014', 'img_f1281', 'img_f1611', 'img_f104', 'img_f667', 'img_f531', 'img_f683', 'img_f1542', 'img_f886', 'img_f826', 'img_f1975', 'img_f1721', 'img_f1350', 'img_f903', 'img_f1648', 'img_f1320', 'img_f1555', 'img_f1599', 'img_f1995', 'img_f279', 'img_f1408', 'img_f746', 'img_f1477', 'img_f1800', 'img_f1808', 'img_f513', 'img_f1944', 'img_f1394', 'img_f833', 'img_f541', 'img_f1732', 'img_f1854', 'img_f600', 'img_f1030', 'img_f1058', 'img_f2017', 'img_f381', 'img_f922', 'img_f1368', 'img_f1502', 'img_f851', 'img_f1113', 'img_f1041', 'img_f942', 'img_f215', 'img_f234', 'img_f1444', 'img_f647', 'img_f1426', 'img_f990', 'img_f693', 'img_f15', 'img_f935', 'img_f1168', 'img_f1242', 'img_f1167', 'img_f984', 'img_f26', 'img_f756', 'img_f179', 'img_f741', 'img_f1865', 'img_f1943', 'img_f1942', 'img_f1342', 'img_f151', 'img_f29', 'img_f1567', 'img_f507', 'img_f241', 'img_f1910', 'img_f60', 'img_f2031', 'img_f817', 'img_f1049', 'img_f1968', 'img_f981', 'img_f1546', 'img_f91', 'img_f323', 'img_f701', 'img_f1205', 'img_f1716', 'img_f1843', 'img_f1071', 'img_f1107', 'img_f1463', 'img_f1752', 'img_f1946', 'img_f1864', 'img_f1631', 'img_f1165', 'img_f788', 'img_f1901', 'img_f1905', 'img_f745', 'img_f1667', 'img_f469', 'img_f36', 'img_f2002', 'img_f999', 'img_f1331', 'img_f1238', 'img_f1307', 'img_f580', 'img_f1355', 'img_f1068', 'img_f1382', 'img_f1972', 'img_f1509', 'img_f398', 'img_f134', 'img_f1337', 'img_f528', 'img_f697', 'img_f1379', 'img_f1691', 'img_f839', 'img_f847', 'img_f723', 'img_f725', 'img_f1479', 'img_f1442', 'img_f282', 'img_f445', 'img_f438', 'img_f1566', 'img_f1613', 'img_f1994', 'img_f966', 'img_f1403', 'img_f125', 'img_f116', 'img_f114', 'img_f1616', 'img_f238', 'img_f1700', 'img_f97', 'img_f1178', 'img_f526', 'img_f42', 'img_f1038', 'img_f1034', 'img_f1027', 'img_f1819', 'img_f1480', 'img_f767', 'img_f636', 'img_f1971', 'img_f52', 'img_f1347', 'img_f1142', 'img_f1967', 'img_f1916', 'img_f1893', 'img_f1877', 'img_f304', 'img_f1356', 'img_f593', 'img_f1308', 'img_f236', 'img_f242', 'img_f220', 'img_f183', 'img_f1641', 'img_f810', 'img_f1078', 'img_f1301', 'img_f5', 'img_f18', 'Wind_Run', 'img_f911', 'img_f890', 'img_f1551', 'img_f1534', 'img_f1545', 'img_f368', 'img_f364', 'img_f1973', 'img_f1535', 'img_f1001', 'img_f721', 'img_f353', 'img_f1588', 'img_f1558', 'img_f2023', 'img_f1596', 'img_f385', 'img_f396', 'img_f1478', 'img_f422', 'img_f1640', 'img_f835', 'img_f1076', 'img_f1315', 'img_f1303', 'img_f581', 'img_f219', 'img_f224', 'img_f1719', 'img_f1729', 'img_f1727', 'img_f557', 'img_f564', 'img_f49', 'img_f1248', 'img_f1244', 'img_f616', 'img_f1270', 'img_f1291', 'img_f300', 'img_f1139', 'img_f759', 'img_f1785', 'img_f630', 'img_f650', 'img_f1267', 'img_f1949', 'img_f758', 'img_f1120', 'img_f1821', 'img_f144', 'img_f698', 'img_f1214', 'img_f659', 'img_f1799', 'img_f988', 'img_f781', 'img_f94', 'img_f1192', 'img_f1 ...
#
# Final shape
# (145, 1549)
#
# Saved to val processed_data.csv

# %%
import pandas as pd

df = df_reduced_test.copy()


label_map = {
    "FRESH": 0,
    "BLOAT": 1,
    "ACTIVE_DECAY": 2,
    "ADVANCED_DECAY": 3
}
df["class_label_encoded"] = df["class_label"].map(label_map)

# check mapping
print("Encoded target preview")
print(df[["class_label", "class_label_encoded"]].drop_duplicates())


numeric_cols = df.select_dtypes(include=["number"]).columns.tolist()
string_cols = df.select_dtypes(include=["object", "string"]).columns.tolist()


print("\nNumeric columns")
print(numeric_cols)

print("\nString columns")
print(string_cols)


print("\nString columns with unique counts")
for col in string_cols:
    print(f"{col}: unique={df[col].nunique(dropna=True)}, avg_len={df[col].astype(str).str.len().mean():.2f}")

target_col = "class_label_encoded"
raw_target_col = "class_label"


# input categorical columns only
categorical_cols = ["wind_dir", "season"]
categorical_cols = [c for c in categorical_cols if c in df.columns]

print("\nTarget column")
print(target_col)

print("\nInput categorical columns")
print(categorical_cols)


df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=False)
df_encoded = df_encoded.drop(columns=[raw_target_col], errors="ignore")

print("\nFinal columns after one-hot encoding")
print(df_encoded.columns.tolist())

print("\nFinal shape")
print(df_encoded.shape)

df_encoded.to_csv("./metadata_split/test_processed_data.csv", index=False)
print("\nSaved to test processed_data.csv")
# Out:
# Encoded target preview
#        class_label  class_label_encoded
# 0            FRESH                    0
# 15           BLOAT                    1
# 49    ACTIVE_DECAY                    2
# 86  ADVANCED_DECAY                    3
#
# Numeric columns
# ['year', 'img_f397', 'img_f492', 'img_f339', 'img_f392', 'img_f142', 'img_f311', 'img_f743', 'img_f888', 'img_f1947', 'img_f1763', 'img_f1123', 'img_f1806', 'img_f1713', 'img_f1549', 'img_f1260', 'img_f1105', 'img_f1018', 'img_f27', 'img_f38', 'img_f840', 'img_f1639', 'img_f92', 'img_f764', 'img_f14', 'img_f1170', 'img_f496', 'img_f717', 'img_f879', 'img_f558', 'img_f1871', 'img_f1133', 'img_f994', 'img_f335', 'img_f1309', 'img_f1271', 'img_f809', 'img_f2047', 'img_f987', 'img_f30', 'img_f1373', 'img_f1458', 'img_f58', 'img_f1295', 'img_f1625', 'img_f1243', 'img_f674', 'img_f246', 'img_f1998', 'img_f744', 'img_f1501', 'img_f657', 'img_f898', 'img_f974', 'img_f1924', 'img_f1881', 'img_f211', 'img_f931', 'img_f1411', 'img_f1204', 'img_f93', 'img_f2042', 'img_f410', 'img_f1985', 'img_f1572', 'img_f379', 'img_f21', 'img_f459', 'img_f798', 'img_f1635', 'img_f1391', 'img_f1199', 'img_f248', 'img_f1016', 'img_f1423', 'img_f1000', 'img_f1457', 'img_f88', 'img_f175', 'img_f926', 'img_f753', 'img_f250', 'img_f1388', 'img_f370', 'img_f357', 'img_f1844', 'img_f446', 'img_f1805', 'img_f1327', 'img_f324', 'img_f1696', 'img_f1014', 'img_f1281', 'img_f1611', 'img_f104', 'img_f667', 'img_f531', 'img_f683', 'img_f1542', 'img_f886', 'img_f826', 'img_f1975', 'img_f1721', 'img_f1350', 'img_f903', 'img_f1648', 'img_f1320', 'img_f1555', 'img_f1599', 'img_f1995', 'img_f279', 'img_f1408', 'img_f746', 'img_f1477', 'img_f1800', 'img_f1808', 'img_f513', 'img_f1944', 'img_f1394', 'img_f833', 'img_f541', 'img_f1732', 'img_f1854', 'img_f600', 'img_f1030', 'img_f1058', 'img_f2017', 'img_f381', 'img_f922', 'img_f1368', 'img_f1502', 'img_f851', 'img_f1113', 'img_f1041', 'img_f942', 'img_f215', 'img_f234', 'img_f1444', 'img_f647', 'img_f1426', 'img_f990', 'img_f693', 'img_f15', 'img_f935', 'img_f1168', 'img_f1242', 'img_f1167', 'img_f984', 'img_f26', 'img_f756', 'img_f179', 'img_f741', 'img_f1865', 'img_f1943', 'img_f1942', 'img_f1342', 'img_f151', 'img_f29', 'img_f1567', 'img_f507', 'img_f241', 'img_f1910', 'img_f60', 'img_f2031', 'img_f817', 'img_f1049', 'img_f1968', 'img_f981', 'img_f1546', 'img_f91', 'img_f323', 'img_f701', 'img_f1205', 'img_f1716', 'img_f1843', 'img_f1071', 'img_f1107', 'img_f1463', 'img_f1752', 'img_f1946', 'img_f1864', 'img_f1631', 'img_f1165', 'img_f788', 'img_f1901', 'img_f1905', 'img_f745', 'img_f1667', 'img_f469', 'img_f36', 'img_f2002', 'img_f999', 'img_f1331', 'img_f1238', 'img_f1307', 'img_f580', 'img_f1355', 'img_f1068', 'img_f1382', 'img_f1972', 'img_f1509', 'img_f398', 'img_f134', 'img_f1337', 'img_f528', 'img_f697', 'img_f1379', 'img_f1691', 'img_f839', 'img_f847', 'img_f723', 'img_f725', 'img_f1479', 'img_f1442', 'img_f282', 'img_f445', 'img_f438', 'img_f1566', 'img_f1613', 'img_f1994', 'img_f966', 'img_f1403', 'img_f125', 'img_f116', 'img_f114', 'img_f1616', 'img_f238', 'img_f1700', 'img_f97', 'img_f1178', 'img_f526', 'img_f42', 'img_f1038', 'img_f1034', 'img_f1027', 'img_f1819', 'img_f1480', 'img_f767', 'img_f636', 'img_f1971', 'img_f52', 'img_f1347', 'img_f1142', 'img_f1967', 'img_f1916', 'img_f1893', 'img_f1877', 'img_f304', 'img_f1356', 'img_f593', 'img_f1308', 'img_f236', 'img_f242', 'img_f220', 'img_f183', 'img_f1641', 'img_f810', 'img_f1078', 'img_f1301', 'img_f5', 'img_f18', 'Wind_Run', 'img_f911', 'img_f890', 'img_f1551', 'img_f1534', 'img_f1545', 'img_f368', 'img_f364', 'img_f1973', 'img_f1535', 'img_f1001', 'img_f721', 'img_f353', 'img_f1588', 'img_f1558', 'img_f2023', 'img_f1596', 'img_f385', 'img_f396', 'img_f1478', 'img_f422', 'img_f1640', 'img_f835', 'img_f1076', 'img_f1315', 'img_f1303', 'img_f581', 'img_f219', 'img_f224', 'img_f1719', 'img_f1729', 'img_f1727', 'img_f557', 'img_f564', 'img_f49', 'img_f1248', 'img_f1244', 'img_f616', 'img_f1270', 'img_f1291', 'img_f300', 'img_f1139', 'img_f759', 'img_f1785', 'img_f630', 'img_f650', 'img_f1267', 'img_f1949', 'img_f758', 'img_f1120', 'img_f1821', 'img_f144', 'img_f698', 'img_f1214', 'img_f659', 'img_f1799', 'img_f988', 'img_f781', 'img_f94', 'img_f1192', 'img_f1 ...
#
# String columns
# ['class_label', 'wind_dir', 'season']
#
# String columns with unique counts
# class_label: unique=4, avg_len=10.50
# wind_dir: unique=6, avg_len=2.67
# season: unique=2, avg_len=6.00
#
# Target column
# class_label_encoded
#
# Input categorical columns
# ['wind_dir', 'season']
#
# Final columns after one-hot encoding
# ['year', 'img_f397', 'img_f492', 'img_f339', 'img_f392', 'img_f142', 'img_f311', 'img_f743', 'img_f888', 'img_f1947', 'img_f1763', 'img_f1123', 'img_f1806', 'img_f1713', 'img_f1549', 'img_f1260', 'img_f1105', 'img_f1018', 'img_f27', 'img_f38', 'img_f840', 'img_f1639', 'img_f92', 'img_f764', 'img_f14', 'img_f1170', 'img_f496', 'img_f717', 'img_f879', 'img_f558', 'img_f1871', 'img_f1133', 'img_f994', 'img_f335', 'img_f1309', 'img_f1271', 'img_f809', 'img_f2047', 'img_f987', 'img_f30', 'img_f1373', 'img_f1458', 'img_f58', 'img_f1295', 'img_f1625', 'img_f1243', 'img_f674', 'img_f246', 'img_f1998', 'img_f744', 'img_f1501', 'img_f657', 'img_f898', 'img_f974', 'img_f1924', 'img_f1881', 'img_f211', 'img_f931', 'img_f1411', 'img_f1204', 'img_f93', 'img_f2042', 'img_f410', 'img_f1985', 'img_f1572', 'img_f379', 'img_f21', 'img_f459', 'img_f798', 'img_f1635', 'img_f1391', 'img_f1199', 'img_f248', 'img_f1016', 'img_f1423', 'img_f1000', 'img_f1457', 'img_f88', 'img_f175', 'img_f926', 'img_f753', 'img_f250', 'img_f1388', 'img_f370', 'img_f357', 'img_f1844', 'img_f446', 'img_f1805', 'img_f1327', 'img_f324', 'img_f1696', 'img_f1014', 'img_f1281', 'img_f1611', 'img_f104', 'img_f667', 'img_f531', 'img_f683', 'img_f1542', 'img_f886', 'img_f826', 'img_f1975', 'img_f1721', 'img_f1350', 'img_f903', 'img_f1648', 'img_f1320', 'img_f1555', 'img_f1599', 'img_f1995', 'img_f279', 'img_f1408', 'img_f746', 'img_f1477', 'img_f1800', 'img_f1808', 'img_f513', 'img_f1944', 'img_f1394', 'img_f833', 'img_f541', 'img_f1732', 'img_f1854', 'img_f600', 'img_f1030', 'img_f1058', 'img_f2017', 'img_f381', 'img_f922', 'img_f1368', 'img_f1502', 'img_f851', 'img_f1113', 'img_f1041', 'img_f942', 'img_f215', 'img_f234', 'img_f1444', 'img_f647', 'img_f1426', 'img_f990', 'img_f693', 'img_f15', 'img_f935', 'img_f1168', 'img_f1242', 'img_f1167', 'img_f984', 'img_f26', 'img_f756', 'img_f179', 'img_f741', 'img_f1865', 'img_f1943', 'img_f1942', 'img_f1342', 'img_f151', 'img_f29', 'img_f1567', 'img_f507', 'img_f241', 'img_f1910', 'img_f60', 'img_f2031', 'img_f817', 'img_f1049', 'img_f1968', 'img_f981', 'img_f1546', 'img_f91', 'img_f323', 'img_f701', 'img_f1205', 'img_f1716', 'img_f1843', 'img_f1071', 'img_f1107', 'img_f1463', 'img_f1752', 'img_f1946', 'img_f1864', 'img_f1631', 'img_f1165', 'img_f788', 'img_f1901', 'img_f1905', 'img_f745', 'img_f1667', 'img_f469', 'img_f36', 'img_f2002', 'img_f999', 'img_f1331', 'img_f1238', 'img_f1307', 'img_f580', 'img_f1355', 'img_f1068', 'img_f1382', 'img_f1972', 'img_f1509', 'img_f398', 'img_f134', 'img_f1337', 'img_f528', 'img_f697', 'img_f1379', 'img_f1691', 'img_f839', 'img_f847', 'img_f723', 'img_f725', 'img_f1479', 'img_f1442', 'img_f282', 'img_f445', 'img_f438', 'img_f1566', 'img_f1613', 'img_f1994', 'img_f966', 'img_f1403', 'img_f125', 'img_f116', 'img_f114', 'img_f1616', 'img_f238', 'img_f1700', 'img_f97', 'img_f1178', 'img_f526', 'img_f42', 'img_f1038', 'img_f1034', 'img_f1027', 'img_f1819', 'img_f1480', 'img_f767', 'img_f636', 'img_f1971', 'img_f52', 'img_f1347', 'img_f1142', 'img_f1967', 'img_f1916', 'img_f1893', 'img_f1877', 'img_f304', 'img_f1356', 'img_f593', 'img_f1308', 'img_f236', 'img_f242', 'img_f220', 'img_f183', 'img_f1641', 'img_f810', 'img_f1078', 'img_f1301', 'img_f5', 'img_f18', 'Wind_Run', 'img_f911', 'img_f890', 'img_f1551', 'img_f1534', 'img_f1545', 'img_f368', 'img_f364', 'img_f1973', 'img_f1535', 'img_f1001', 'img_f721', 'img_f353', 'img_f1588', 'img_f1558', 'img_f2023', 'img_f1596', 'img_f385', 'img_f396', 'img_f1478', 'img_f422', 'img_f1640', 'img_f835', 'img_f1076', 'img_f1315', 'img_f1303', 'img_f581', 'img_f219', 'img_f224', 'img_f1719', 'img_f1729', 'img_f1727', 'img_f557', 'img_f564', 'img_f49', 'img_f1248', 'img_f1244', 'img_f616', 'img_f1270', 'img_f1291', 'img_f300', 'img_f1139', 'img_f759', 'img_f1785', 'img_f630', 'img_f650', 'img_f1267', 'img_f1949', 'img_f758', 'img_f1120', 'img_f1821', 'img_f144', 'img_f698', 'img_f1214', 'img_f659', 'img_f1799', 'img_f988', 'img_f781', 'img_f94', 'img_f1192', 'img_f1 ...
#
# Final shape
# (147, 1548)
#
# Saved to test processed_data.csv

# %%
import numpy as np
import pandas as pd

train_df = pd.read_csv("metadata_split/train_processed_data.csv")
val_df   = pd.read_csv("metadata_split/val_processed_data.csv")
test_df  = pd.read_csv("metadata_split/test_processed_data.csv")

# identify numeric columns
numeric_cols = train_df.select_dtypes(include=[np.number]).columns.tolist()

# fill numeric NaNs using TRAIN medians
train_medians = train_df[numeric_cols].median()

train_df[numeric_cols] = train_df[numeric_cols].fillna(train_medians)
val_df[numeric_cols]   = val_df[numeric_cols].fillna(train_medians)
test_df[numeric_cols]  = test_df[numeric_cols].fillna(train_medians)

print("train total nan:", train_df.isna().sum().sum())
print("val total nan:", val_df.isna().sum().sum())
print("test total nan:", test_df.isna().sum().sum())

# # save cleaned versions
# train_df.to_csv("metadata_split/train_process_clean.csv", index=False)
# val_df.to_csv("metadata_split/val_process_clean.csv", index=False)
# test_df.to_csv("metadata_split/test_process_clean.csv", index=False)

# print("Saved cleaned CSVs.")
# Out:
# train total nan: 0
# val total nan: 0
# test total nan: 0

# %%
train_df.head()
# Out:
#    year  img_f397  img_f492  img_f339  img_f392  img_f142  img_f311  img_f743  \
# 0  2011  0.594061  1.504402  0.000000       0.0  1.114413  0.000005       0.0
# 1  2011  0.276269  1.085566  0.000000       0.0  0.868110  0.031464       0.0
# 2  2011  1.149455  0.518478  0.000000       0.0  6.389708  0.396701       0.0
# 3  2011  0.495224  0.209895  0.046165       0.0  3.614911  0.155939       0.0
# 4  2011  0.400659  0.206734  0.021028       0.0  4.472982  0.530318       0.0
#
#    img_f888  img_f1947  ...   img_f59  img_f679  img_f1419  \
# 0       0.0   0.849036  ...  0.128094  0.000000   0.000000
# 1       0.0   0.138654  ...  0.132429  0.077721   0.000000
# 2       0.0   0.007070  ...  0.087417  0.023505   0.013536
# 3       0.0   0.112406  ...  0.000000  0.087811   0.000000
# 4       0.0   0.133996  ...  0.019594  0.002594   0.036342
#
#    class_label_encoded  wind_dir_---  wind_dir_N  wind_dir_NNE  wind_dir_SSW  \
# 0                    0         False       False          True         False
# 1                    0         False       False          True         False
# 2                    0         False       False          True         False
# 3                    0         False       False          True         False
# 4                    0         False       False          True         False
#
#    season_Spring  season_Winter
# 0          False           True
# 1          False           True
# 2          False           True
# 3          False           True
# 4          False           True
#
# [5 rows x 1546 columns]

# %%
val_df.head()
# Out:
#    year  img_f397  img_f492  img_f339  img_f392  img_f142  img_f311  img_f743  \
# 0  2011  0.239870  0.235464  0.000000       0.0  0.285234  0.120568       0.0
# 1  2011  0.267841  0.073997  0.025231       0.0  0.261868  0.041774       0.0
# 2  2011  0.491070  0.266679  0.000000       0.0  1.883064  0.121044       0.0
# 3  2011  1.087132  0.745814  0.000000       0.0  0.727413  0.183669       0.0
# 4  2011  0.288732  0.000142  0.000000       0.0  0.542921  0.039009       0.0
#
#    img_f888  img_f1947  ...   img_f59  img_f679  img_f1419  \
# 0  0.000000   0.599407  ...  0.088168  0.000000        0.0
# 1  0.000000   0.411599  ...  0.327065  0.050561        0.0
# 2  0.000000   0.572409  ...  0.207531  0.000000        0.0
# 3  0.030307   0.476472  ...  0.121708  0.000000        0.0
# 4  0.000000   0.001757  ...  0.000000  0.000000        0.0
#
#    class_label_encoded  wind_dir_---  wind_dir_N  wind_dir_NNE  wind_dir_SSW  \
# 0                    0         False       False          True         False
# 1                    0         False       False          True         False
# 2                    0         False       False          True         False
# 3                    0         False       False          True         False
# 4                    0         False       False          True         False
#
#    season_Spring  season_Winter
# 0          False           True
# 1          False           True
# 2          False           True
# 3          False           True
# 4          False           True
#
# [5 rows x 1546 columns]

# %%
test_df.head()
# Out:
#    year  img_f397  img_f492  img_f339  img_f392  img_f142  img_f311  img_f743  \
# 0  2012  0.969437  1.980332  0.003121  0.383500  0.348109  0.124442  0.000000
# 1  2012  0.493326  0.379300  0.000000  0.077665  0.141502  0.026641  0.000000
# 2  2012  0.386471  0.466571  0.000000  0.013693  0.910888  0.411789  0.026101
# 3  2012  0.422241  0.104161  0.000000  0.000000  0.865137  0.000000  0.000000
# 4  2012  1.104393  2.181820  0.000000  0.425594  0.559976  0.084818  0.000000
#
#    img_f888  img_f1947  ...   img_f59  img_f679  img_f1419  \
# 0  0.008419   0.111737  ...  0.592261  0.015116   0.000000
# 1  0.000000   0.013809  ...  0.787830  0.071438   0.000000
# 2  0.023986   0.388476  ...  0.906912  0.093578   0.059056
# 3  0.000000   0.008571  ...  0.567307  0.000000   0.000000
# 4  0.085991   0.020233  ...  1.692416  0.062241   0.000000
#
#    class_label_encoded  wind_dir_---  wind_dir_N  wind_dir_NNE  wind_dir_SSW  \
# 0                    0         False       False          True         False
# 1                    0         False       False          True         False
# 2                    0         False       False          True         False
# 3                    0         False       False          True         False
# 4                    0         False       False          True         False
#
#    season_Spring  season_Winter
# 0          False           True
# 1          False           True
# 2          False           True
# 3          False           True
# 4          False           True
#
# [5 rows x 1546 columns]
